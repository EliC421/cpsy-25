# %% [markdown]
# # Visualize the count for each number of in list 'numbers' for dict extracted from json `res/better_dict.json`

# %%
import json
import pandas as pandas
import matplotlib.pyplot as pyplot
import seaborn as sns

dic = json.load(open('res/better_dict.json'))
dic
# Out:
# {'sub-GE120001': {'count': 1, 'numbers': []},
#  'sub-GE120002': {'count': 1, 'numbers': []},
#  'sub-GE120003': {'count': 1, 'numbers': []},
#  'sub-GE120004': {'count': 1, 'numbers': []},
#  'sub-GE120005': {'count': 1, 'numbers': []},
#  'sub-GE120006': {'count': 1, 'numbers': []},
#  'sub-GE120008': {'count': 1, 'numbers': []},
#  'sub-GE120010': {'count': 1, 'numbers': []},
#  'sub-GE120011': {'count': 1, 'numbers': []},
#  'sub-GE120012': {'count': 1, 'numbers': []},
#  'sub-GE120013': {'count': 1, 'numbers': []},
#  'sub-GE120014': {'count': 1, 'numbers': []},
#  'sub-GE120015': {'count': 1, 'numbers': []},
#  'sub-GE120017': {'count': 1, 'numbers': []},
#  'sub-GE120018': {'count': 1, 'numbers': []},
#  'sub-GE120019': {'count': 1, 'numbers': []},
#  'sub-GE120020': {'count': 1, 'numbers': []},
#  'sub-GE120021': {'count': 1, 'numbers': []},
#  'sub-GE120023': {'count': 1, 'numbers': []},
#  'sub-GE120024': {'count': 1, 'numbers': []},
# ...

# %%
# from dic to df sub as index col = count , numebrs
df = pandas.DataFrame(dic)
df = df.T
df = df.reset_index()
df
# Out:
#            index count numbers
# 0   sub-GE120001     1      []
# 1   sub-GE120002     1      []
# 2   sub-GE120003     1      []
# 3   sub-GE120004     1      []
# 4   sub-GE120005     1      []
# ..           ...   ...     ...
# 60  sub-GE120080     1      []
# 61  sub-GE120081     1      []
# 62  sub-GE120082     1      []
# 63  sub-GE120083     1      []
# 64  sub-GE120084     1      []
#
# [65 rows x 3 columns]
